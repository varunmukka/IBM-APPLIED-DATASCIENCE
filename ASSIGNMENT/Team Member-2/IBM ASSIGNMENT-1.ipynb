# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

# %%
card_approval_df=pd.read_csv('/content/House Price India.csv')
print(card_approval_df.head())
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
print(card_approval_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
card_approval_df[['id','Date','Built Year','Price','living area']].describe()
# Out:
#                  id          Date    Built Year         Price   living area
# count  1.462000e+04  14620.000000  14620.000000  1.462000e+04  14620.000000
# mean   6.762821e+09  42604.538646   1970.926402  5.389322e+05   2098.262996
# std    6.237575e+03     67.347991     29.493625  3.675324e+05    928.275721
# min    6.762810e+09  42491.000000   1900.000000  7.800000e+04    370.000000
# 25%    6.762815e+09  42546.000000   1951.000000  3.200000e+05   1440.000000
# 50%    6.762821e+09  42600.000000   1975.000000  4.500000e+05   1930.000000
# 75%    6.762826e+09  42662.000000   1997.000000  6.450000e+05   2570.000000
# max    6.762832e+09  42734.000000   2015.000000  7.700000e+06  13540.000000

# %%
sns.histplot(card_approval_df.Date,kde=True)
# Out:
# <Axes: xlabel='Date', ylabel='Count'>

# %%
sns.histplot(card_approval_df.Price,kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
# plot count plot for the gender column
sns.countplot(card_approval_df.id)
# Out:
# <Axes: ylabel='count'>

# %%
# plot count plot for the gender column
sns.countplot(card_approval_df.Lattitude)
# Out:
# <Axes: ylabel='count'>

# %%
card_approval_df.boxplot(column='living area')
# Out:
# <Axes: >

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
card_approval_df.plot(x='living area',y='number of bedrooms')
# Out:
# <Axes: xlabel='living area'>

# %%
card_approval_df.plot.scatter(x='living area',y='number of bedrooms')
# Out:
# <Axes: xlabel='living area', ylabel='number of bedrooms'>

# %%
card_approval_df.plot.hexbin(x='living area',y='number of bedrooms')
# Out:
# <Axes: xlabel='living area', ylabel='number of bedrooms'>

# %%
card_approval_df.plot.bar(x='living area',y='number of bedrooms')
# Out:
# <Axes: xlabel='living area'>

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
sns.pairplot(data=card_approval_df[['id','Date','number of bedrooms','number of bathrooms','living area','grade of the house']])

# %% [markdown]
# DESCRIPTION STATISTICS

# %%
#data=card_approval_df.describe()
df = pd.DataFrame(card_approval_df)
print (df)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %% [markdown]
# NULL HANDLING

# %%
data=card_approval_df.isna().sum()
print(data)
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...
